# %%
import numpy as np 

import pandas as pd
import os, sys, email

# %%
emailclean_df = pd.read_csv('D:\enron-email-dataset\output.csv')

# %%
emailclean_df = emailclean_df.reset_index().drop_duplicates(subset='content', keep='last').set_index('index')


len(emailclean_df)
# Out:
# 249025

# %%
emailclean_df.to_csv("D:\enron-email-dataset\duplicate.csv")

# %%
emailclean_df
# Out:
#                                            Message-ID  \
# index
# 664     <12929996.1075855668941.JavaMail.evans@thyme>
# 715     <13537630.1075855669909.JavaMail.evans@thyme>
# 842     <17449361.1075855672476.JavaMail.evans@thyme>
# 993     <27798412.1075855696053.JavaMail.evans@thyme>
# 1196    <12635597.1075855702772.JavaMail.evans@thyme>
# 1230    <15816310.1075855374294.JavaMail.evans@thyme>
# 1231     <6521706.1075855374316.JavaMail.evans@thyme>
# 1232    <21543395.1075855374340.JavaMail.evans@thyme>
# 1233    <25363451.1075855374674.JavaMail.evans@thyme>
# 1234    <19705494.1075858631723.JavaMail.evans@thyme>
# 1235     <7996335.1075858632216.JavaMail.evans@thyme>
# 1240    <21687871.1075858632365.JavaMail.evans@thyme>
# 1242    <27972496.1075858632410.JavaMail.evans@thyme>
# 1245    <19855186.1075858632468.JavaMail.evans@thyme>
# 1247    <22988326.1075858632512.JavaMail.evans@thyme>
# 1248    <19068890.1075858632535.JavaMail.evans@thyme>
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-af02ad852bf7> in <module>()
# ----> 1 emailclean_df(['content']).BeautifulSoup()
#
# TypeError: 'DataFrame' object is not callable
